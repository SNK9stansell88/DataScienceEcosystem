# %% [markdown]
# <a href="https://colab.research.google.com/github/SNK9stansell88/DataScienceEcosystem/blob/main/01_safe_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quickstart Notebook (Safe Test)
#
# This notebook is a **known-good** file to confirm GitHub rendering and Colab open work correctly.
#
# **How to use:**
# 1. Click **Open in Colab** (top-right) after committing this file.
# 2. Run the cells to verify Python + pandas are working.
# 3. Once this renders properly, we can re-add your project notebooks safely.

# %%
# Environment check — this should run in both GitHub (render only) and Colab (run)
import sys, platform
print("✅ Python:", sys.version.split()[0])
print("✅ Platform:", platform.platform())

# %%
# Minimal pandas test — creates a small table and shows the first rows
import pandas as pd
df = pd.DataFrame({
    "medication": ["Ketamine", "Fentanyl", "Epinephrine"],
    "events": [12, 8, 5]
})
df

# %% [markdown]
# ## Next steps (after this file renders)
#
# - Use **File → Save a copy in GitHub…** from a *working* Colab notebook to publish it here without corruption.
# - Or upload a downloaded `.ipynb` via **Add file → Upload files**.
# - Keep project notebooks under `notebooks/`.
